# %%
import pandas as pd
employee={
    "firstname":["faiz","manav","forum","mishri","astha","brijesh"],
    "salary":[15500,16500,17500,18500,19500,20500]
}
# create dataframes 

df=pd.DataFrame(employee)
print(df)
print(df.min())
print(df.max())
# Out:
#   firstname  salary
# 0      faiz   15500
# 1     manav   16500
# 2     forum   17500
# 3    mishri   18500
# 4     astha   19500
# 5   brijesh   20500
# firstname    astha
# salary       15500
# dtype: object
# firstname    mishri
# salary        20500
# dtype: object
