# %%
# w.a.p to check eligibility 
age=int(input('Enter your age :'))
if age>=18:
        print('i am eligible for vote')
else:
        print('i am not eligible for voting')
# Out:
#   Cell In[2], line 2
#     age=int(input('Enter your age :')
#            ^
# SyntaxError: '(' was never closed
